# %% [markdown]
# # Merge

# %%
import pandas as pd

# %% [markdown]
# __Ejercicio 1:__

# %% [markdown]
# Utilizar pandas para importar los datos del archivo "merge.xlsx" en la variable "consultas"

# %%
consultas=pd.read_excel("../merge.xlsx", index_col="id")
consultas
# Out:
#                    paciente  doctor
# id
# 1       Carla Medina Huerta     1.0
# 2    Francisco Saucedo Rojo     2.0
# 3   Amelia Verduzco Ondarza     1.0
# 4      Eva Guevara Escobedo     1.0
# 5   Moises Peñalosa Barajas     4.0
# 6       Ismael Orozco Mejía     NaN

# %% [markdown]
# __Ejercicio 2:__

# %% [markdown]
# Utilizar pandas para importar los datos en la hoja "doctor" del archivo "merge.xlsx"  en la variable "doctores"

# %%
doctores=pd.read_excel("../merge.xlsx", sheet_name="doctor", index_col="id")
doctores.head()
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %% [markdown]
# __Ejercicio 3:__

# %% [markdown]
# Utilizar pandas para importar los datos en la hoja "especialidades" del archivo "merge.xlsx" en la variable "especialidades"

# %%
especialidades=pd.read_excel("../merge.xlsx", sheet_name="especialidades", header=3, usecols="B:D", index_col="id_especialidad")
especialidades.head()
# Out:
#                             nombre  \
# id_especialidad
# 1                   Anestesiología
# 2                      Cardiología
# 3                Gastroenterología
# 4                      Hematología
# 5                 Cirugía Plástica
#
#                                                        descripcion
# id_especialidad
# 1                 La anestesiología es la rama médica que se en...
# 2                La cardiología es la rama de la medicina que s...
# 3                La gastroenterología es la especialidad médica...
# 4                La hematología ​ es la especialidad médica que...
# 5                Atiende y trata en forma médico-quirúrgica tod...

# %% [markdown]
# __Ejercicio 4:__

# %% [markdown]
# Utilizar la función join para unir los dataframe doctores y especialidades en base a la columna "id_especialidad"

# %%
doctores.join(especialidades, on = "id_especialidad")
# Out:
#                     doctor  id_especialidad  consultorio             nombre  \
# id
# 1     Camilo Iglesias Lima                2          101        Cardiología
# 2   Claudio Gamba Cisneros                1          102     Anestesiología
# 3     Anibal Prado Mendoza                1          102     Anestesiología
# 4      Rocío Pastor Pineda                3          101  Gastroenterología
# 5        Kevin Pastor Mora                1          103     Anestesiología
#
#                                           descripcion
# id
# 1   La cardiología es la rama de la medicina que s...
# 2    La anestesiología es la rama médica que se en...
# 3    La anestesiología es la rama médica que se en...
# 4   La gastroenterología es la especialidad médica...
# 5    La anestesiología es la rama médica que se en...

# %% [markdown]
# __Ejercicio 5:__

# %% [markdown]
# Utilizar la función join para unir los dataframe consultas y doctores en base a la columna "doctor", agregar el sufico "_id" a la columna doctor del Dataframe izquierdo

# %%
consultas.join(doctores, on = "doctor", lsuffix="_id")
# Out:
#                    paciente  doctor_id                  doctor  \
# id
# 1       Carla Medina Huerta        1.0    Camilo Iglesias Lima
# 2    Francisco Saucedo Rojo        2.0  Claudio Gamba Cisneros
# 3   Amelia Verduzco Ondarza        1.0    Camilo Iglesias Lima
# 4      Eva Guevara Escobedo        1.0    Camilo Iglesias Lima
# 5   Moises Peñalosa Barajas        4.0     Rocío Pastor Pineda
# 6       Ismael Orozco Mejía        NaN                     NaN
#
#     id_especialidad  consultorio
# id
# 1               2.0        101.0
# 2               1.0        102.0
# 3               2.0        101.0
# 4               2.0        101.0
# 5               3.0        101.0
# 6               NaN          NaN

# %%
doctores
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %% [markdown]
# __Ejercicio 6:__

# %% [markdown]
# Ordenar el DataFrame anterior en base a la columna "doctor"

# %%
consultas.join(doctores, on = "doctor", lsuffix="_id" , sort=True)
# Out:
#                    paciente  doctor_id                  doctor  \
# id
# 1       Carla Medina Huerta        1.0    Camilo Iglesias Lima
# 3   Amelia Verduzco Ondarza        1.0    Camilo Iglesias Lima
# 4      Eva Guevara Escobedo        1.0    Camilo Iglesias Lima
# 2    Francisco Saucedo Rojo        2.0  Claudio Gamba Cisneros
# 5   Moises Peñalosa Barajas        4.0     Rocío Pastor Pineda
# 6       Ismael Orozco Mejía        NaN                     NaN
#
#     id_especialidad  consultorio
# id
# 1               2.0        101.0
# 3               2.0        101.0
# 4               2.0        101.0
# 2               1.0        102.0
# 5               3.0        101.0
# 6               NaN          NaN

# %% [markdown]
# __Ejercicio 7:__

# %% [markdown]
# Utilizar la función merge para unir los DataFrame doctores y especialidades en base a la columna "id_especialidad"

# %%
pd.merge(doctores,especialidades, on= "id_especialidad")
# Out:
#                    doctor  id_especialidad  consultorio             nombre  \
# 0    Camilo Iglesias Lima                2          101        Cardiología
# 1  Claudio Gamba Cisneros                1          102     Anestesiología
# 2    Anibal Prado Mendoza                1          102     Anestesiología
# 3       Kevin Pastor Mora                1          103     Anestesiología
# 4     Rocío Pastor Pineda                3          101  Gastroenterología
#
#                                          descripcion
# 0  La cardiología es la rama de la medicina que s...
# 1   La anestesiología es la rama médica que se en...
# 2   La anestesiología es la rama médica que se en...
# 3   La anestesiología es la rama médica que se en...
# 4  La gastroenterología es la especialidad médica...

# %%
doctores
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %%
especialidades
# Out:
#                             nombre  \
# id_especialidad
# 1                   Anestesiología
# 2                      Cardiología
# 3                Gastroenterología
# 4                      Hematología
# 5                 Cirugía Plástica
# 6                     Dermatología
#
#                                                        descripcion
# id_especialidad
# 1                 La anestesiología es la rama médica que se en...
# 2                La cardiología es la rama de la medicina que s...
# 3                La gastroenterología es la especialidad médica...
# 4                La hematología ​ es la especialidad médica que...
# 5                Atiende y trata en forma médico-quirúrgica tod...
# 6                La dermatología es una especialidad clínico-qu...

# %% [markdown]
# __Ejercicio 8:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores,para comparar:
# - Utilizar la columna "doctor" en el DataFrame consultas
# - Utilizar el indice en el DataFrame doctores

# %%
consultas
# Out:
#                    paciente  doctor
# id
# 1       Carla Medina Huerta     1.0
# 2    Francisco Saucedo Rojo     2.0
# 3   Amelia Verduzco Ondarza     1.0
# 4      Eva Guevara Escobedo     1.0
# 5   Moises Peñalosa Barajas     4.0
# 6       Ismael Orozco Mejía     NaN

# %%
doctores
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %%
pd.merge(consultas,doctores,left_on="doctor", right_index=True )
# Out:
#     doctor                 paciente  doctor_x                doctor_y  \
# id
# 1      1.0      Carla Medina Huerta       1.0    Camilo Iglesias Lima
# 3      1.0  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima
# 4      1.0     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima
# 2      2.0   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros
# 5      4.0  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda
#
#     id_especialidad  consultorio
# id
# 1                 2          101
# 3                 2          101
# 4                 2          101
# 2                 1          102
# 5                 3          101

# %% [markdown]
# __Ejercicio 9:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame especialidades y doctores, para comparar:
# - Utilizar el indice en el DataFrame especialidades
# - Utilizar la columna "id_especialidad" en el DataFrame doctores

# %%
pd.merge(especialidades, doctores, left_index= True, right_on = "id_especialidad")
# Out:
#                nombre                                        descripcion  \
# id
# 2      Anestesiología   La anestesiología es la rama médica que se en...
# 3      Anestesiología   La anestesiología es la rama médica que se en...
# 5      Anestesiología   La anestesiología es la rama médica que se en...
# 1         Cardiología  La cardiología es la rama de la medicina que s...
# 4   Gastroenterología  La gastroenterología es la especialidad médica...
#
#                     doctor  id_especialidad  consultorio
# id
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 5        Kevin Pastor Mora                1          103
# 1     Camilo Iglesias Lima                2          101
# 4      Rocío Pastor Pineda                3          101

# %% [markdown]
# __Ejercicio 10:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores, para comparar:
#    - Utilizar la columna "doctor" en el DataFrame consultas
#    - Utilizar la columna "id" en el DaraFrame doctores

# %%
consultas
# Out:
#                    paciente  doctor
# id
# 1       Carla Medina Huerta     1.0
# 2    Francisco Saucedo Rojo     2.0
# 3   Amelia Verduzco Ondarza     1.0
# 4      Eva Guevara Escobedo     1.0
# 5   Moises Peñalosa Barajas     4.0
# 6       Ismael Orozco Mejía     NaN

# %%
doctores
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %%
pd.merge(consultas, doctores,left_on="doctor", right_on= "id")
# Out:
#                   paciente  doctor_x                doctor_y  id_especialidad  \
# 0      Carla Medina Huerta       1.0    Camilo Iglesias Lima                2
# 1  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima                2
# 2     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima                2
# 3   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros                1
# 4  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda                3
#
#    consultorio
# 0          101
# 1          101
# 2          101
# 3          102
# 4          101

# %% [markdown]
# __Ejercicio 11:__

# %% [markdown]
# Modificar el DataFrame anterior:
# - Agregar el sufijo "_id" a la columna "doctor" del Dataframe consultas
# - Agregar el sufijo "_nombre" a la columna "doctor" del DataFrame doctores

# %%
pd.merge(consultas, doctores,left_on="doctor", right_on= "id", suffixes=("_id", "_nombre"))
# Out:
#                   paciente  doctor_id           doctor_nombre  \
# 0      Carla Medina Huerta        1.0    Camilo Iglesias Lima
# 1  Amelia Verduzco Ondarza        1.0    Camilo Iglesias Lima
# 2     Eva Guevara Escobedo        1.0    Camilo Iglesias Lima
# 3   Francisco Saucedo Rojo        2.0  Claudio Gamba Cisneros
# 4  Moises Peñalosa Barajas        4.0     Rocío Pastor Pineda
#
#    id_especialidad  consultorio
# 0                2          101
# 1                2          101
# 2                2          101
# 3                1          102
# 4                3          101

# %% [markdown]
# __Ejercicio 12:__

# %% [markdown]
# Modificar el DataFrame anterior, al momento de hacer la unión solo incluir la columna "doctor"

# %%
pd.merge(consultas, doctores[["doctor"]],left_on="doctor", right_on= "id", suffixes=("_id", "_nombre"))
# Out:
#                   paciente  doctor_id           doctor_nombre
# 0      Carla Medina Huerta        1.0    Camilo Iglesias Lima
# 1  Amelia Verduzco Ondarza        1.0    Camilo Iglesias Lima
# 2     Eva Guevara Escobedo        1.0    Camilo Iglesias Lima
# 3   Francisco Saucedo Rojo        2.0  Claudio Gamba Cisneros
# 4  Moises Peñalosa Barajas        4.0     Rocío Pastor Pineda

# %% [markdown]
# __Ejercicio 13:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores, para comparar:
# - Utilizar la columna "doctor" en el DataFrame consultas
# - Utilizar la columna "id" en el DaraFrame doctores
# - Utilizar una unión izquierda

# %%
consultas
# Out:
#                    paciente  doctor
# id
# 1       Carla Medina Huerta     1.0
# 2    Francisco Saucedo Rojo     2.0
# 3   Amelia Verduzco Ondarza     1.0
# 4      Eva Guevara Escobedo     1.0
# 5   Moises Peñalosa Barajas     4.0
# 6       Ismael Orozco Mejía     NaN

# %%
doctores
# Out:
#                     doctor  id_especialidad  consultorio
# id
# 1     Camilo Iglesias Lima                2          101
# 2   Claudio Gamba Cisneros                1          102
# 3     Anibal Prado Mendoza                1          102
# 4      Rocío Pastor Pineda                3          101
# 5        Kevin Pastor Mora                1          103

# %%
pd.merge(consultas, doctores, left_on="doctor", right_on="id", how="left")
# Out:
#                   paciente  doctor_x                doctor_y  id_especialidad  \
# 0      Carla Medina Huerta       1.0    Camilo Iglesias Lima              2.0
# 1   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros              1.0
# 2  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima              2.0
# 3     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima              2.0
# 4  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda              3.0
# 5      Ismael Orozco Mejía       NaN                     NaN              NaN
#
#    consultorio
# 0        101.0
# 1        102.0
# 2        101.0
# 3        101.0
# 4        101.0
# 5          NaN

# %% [markdown]
# __Ejercicio 14:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores, para comparar:
# - Utilizar la columna "doctor" en el DataFrame consultas
# - Utilizar la columna "id" en el DaraFrame doctores
# - Utilizar una unión derecha

# %%
pd.merge(consultas, doctores, left_on="doctor", right_on="id", how="right")
# Out:
#                   paciente  doctor_x                doctor_y  id_especialidad  \
# 0      Carla Medina Huerta       1.0    Camilo Iglesias Lima                2
# 1  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima                2
# 2     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima                2
# 3   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros                1
# 4                      NaN       NaN    Anibal Prado Mendoza                1
# 5  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda                3
# 6                      NaN       NaN       Kevin Pastor Mora                1
#
#    consultorio
# 0          101
# 1          101
# 2          101
# 3          102
# 4          102
# 5          101
# 6          103

# %% [markdown]
# __Ejercicio 15:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores, para comparar:
# - Utilizar la columna "doctor" en el DataFrame consultas
# - Utilizar la columna "id" en el DaraFrame doctores
# - Utilizar una unión exterior

# %%
pd.merge(consultas, doctores, left_on="doctor", right_on="id", how="outer")
# Out:
#                   paciente  doctor_x                doctor_y  id_especialidad  \
# 0      Carla Medina Huerta       1.0    Camilo Iglesias Lima              2.0
# 1  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima              2.0
# 2     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima              2.0
# 3   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros              1.0
# 4  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda              3.0
# 5      Ismael Orozco Mejía       NaN                     NaN              NaN
# 6                      NaN       NaN    Anibal Prado Mendoza              1.0
# 7                      NaN       NaN       Kevin Pastor Mora              1.0
#
#    consultorio
# 0        101.0
# 1        101.0
# 2        101.0
# 3        102.0
# 4        101.0
# 5          NaN
# 6        102.0
# 7        103.0

# %% [markdown]
# __Ejercicio 16:__

# %% [markdown]
# Utilizar la funcion merge para unir los DataFrame consultas y doctores, para comparar:
# - Utilizar la columna "doctor" en el DataFrame consultas
# - Utilizar la columna "id" en el DaraFrame doctores
# - Utilizar una unión externa
# - Indicar la tabla de origen de cada fila

# %%
pd.merge(consultas, doctores, left_on="doctor", right_on="id", how="outer", indicator=True)
# Out:
#                   paciente  doctor_x                doctor_y  id_especialidad  \
# 0      Carla Medina Huerta       1.0    Camilo Iglesias Lima              2.0
# 1  Amelia Verduzco Ondarza       1.0    Camilo Iglesias Lima              2.0
# 2     Eva Guevara Escobedo       1.0    Camilo Iglesias Lima              2.0
# 3   Francisco Saucedo Rojo       2.0  Claudio Gamba Cisneros              1.0
# 4  Moises Peñalosa Barajas       4.0     Rocío Pastor Pineda              3.0
# 5      Ismael Orozco Mejía       NaN                     NaN              NaN
# 6                      NaN       NaN    Anibal Prado Mendoza              1.0
# 7                      NaN       NaN       Kevin Pastor Mora              1.0
#
#    consultorio      _merge
# 0        101.0        both
# 1        101.0        both
# 2        101.0        both
# 3        102.0        both
# 4        101.0        both
# 5          NaN   left_only
# 6        102.0  right_only
# 7        103.0  right_only
